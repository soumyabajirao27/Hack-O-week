# %%
import sys
import numpy
import pandas
import sklearn

print("Python:", sys.executable)
print("NumPy:", numpy.__version__)
print("Pandas:", pandas.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# Python: C:\Users\dilip\anaconda3\envs\ml_env\python.exe
# NumPy: 2.4.6
# Pandas: 3.0.5
# Scikit-learn: 1.9.0

# %%
# ============================================================
# STEP 1: LOAD EDA DATASET
# ============================================================

import pandas as pd
import numpy as np

# Path of the dataset
path = r"C:\1Aaaaaa5thsem\Hackoweek_2\eda_data.csv"

# Load CSV file
df = pd.read_csv(path)

# Display basic information
print("Dataset loaded successfully!")
print("================================")
print("Number of rows    :", df.shape[0])
print("Number of columns :", df.shape[1])

print("\nFirst 5 rows:")
print(df.head())

print("\nColumn names:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)
# Out:
# Dataset loaded successfully!
# ...
# Number of rows    : 742
# Number of columns : 33
#
# First 5 rows:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# ...

# %%
# ============================================================
# STEP 2: CHECK DATASET
# ============================================================

print("Missing values in each column:")
print(df.isnull().sum())

print("\nDuplicate rows:", df.duplicated().sum())

print("\nDataset information:")
df.info()
# Out:
# Missing values in each column:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# hourly               0
# employer_provided    0
# min_salary           0
# max_salary           0
# avg_salary           0
# company_txt          0
# job_state            0
# same_state           0
# age                  0
# python_yn            0
# R_yn                 0
# spark                0
# aws                  0
# excel                0
# job_simp             0
# seniority            0
# desc_len             0
# num_comp             0
# dtype: int64
#
# Duplicate rows: 0
#
# Dataset information:
# <class 'pandas.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# ...

# %%
# ============================================================
# STEP 3: CHECK ML COLUMNS
# ============================================================

columns_to_check = [
    "Rating",
    "age",
    "desc_len",
    "num_comp",
    "avg_salary",
    "python_yn"
]

print(df[columns_to_check].head())

print("\nData types:")
print(df[columns_to_check].dtypes)

print("\nBasic statistics:")
print(df[columns_to_check].describe())
# Out:
#    Rating  age  desc_len  num_comp  avg_salary  python_yn
# 0     3.8   47      2536         0        72.0          1
# 1     3.4   36      4783         0        87.5          1
# 2     4.8   10      3461         0        85.0          1
# 3     3.8   55      3883         3        76.5          1
# 4     2.9   22      2728         3       114.5          1
#
# Data types:
# Rating        float64
# age             int64
# desc_len        int64
# num_comp        int64
# avg_salary    float64
# python_yn       int64
# dtype: object
#
# Basic statistics:
#            Rating         age      desc_len    num_comp  avg_salary  \
# count  742.000000  742.000000    742.000000  742.000000  742.000000
# mean     3.618868   46.591644   3869.545822    1.053908  100.626011
# std      0.801210   53.778815   1521.495868    1.384239   38.855948
# min     -1.000000   -1.000000    407.000000    0.000000   13.500000
# 25%      3.300000   11.000000   2801.000000    0.000000   73.500000
# ...

# %%
# LINEAR REGRESSION


import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

path = r"C:\1Aaaaaa5thsem\Hackoweek_2\eda_data.csv"

df = pd.read_csv(path)

features = ["Rating", "age", "desc_len", "num_comp"]
target = "avg_salary"

for column in features:
    df[column] = pd.to_numeric(df[column], errors="coerce")

df[target] = pd.to_numeric(df[target], errors="coerce")


df = df.dropna(subset=features + [target])

X = df[features]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)



model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)



mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)



print("========== LINEAR REGRESSION ==========")

print("\nNumber of training samples:", len(X_train))
print("Number of testing samples :", len(X_test))

print("\nMean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R2 Score:", r2)



print("\nModel Coefficients:")

for feature, coefficient in zip(features, model.coef_):
    print(feature, ":", coefficient)

print("\nIntercept:", model.intercept_)


new_data = pd.DataFrame({
    "Rating": [4.0],
    "age": [10],
    "desc_len": [3000],
    "num_comp": [2]
})

new_prediction = model.predict(new_data)


print("\n========== NEW PREDICTION ==========")
print("Predicted Average Salary:", new_prediction[0])
# Out:
# ========== LINEAR REGRESSION ==========
#
# Number of training samples: 593
# Number of testing samples : 149
#
# Mean Squared Error (MSE): 1642.209230149984
# Mean Absolute Error (MAE): 31.78498395018018
# R2 Score: -0.004709687515486616
#
# Model Coefficients:
# Rating : 1.9287510900083529
# age : 0.012026046225493685
# desc_len : 0.0018584566360764334
# num_comp : 2.2152818132137986
#
# Intercept: 82.80331438808709
#
# ========== NEW PREDICTION ==========
# Predicted Average Salary: 100.64451274503233

# %%
#POLYNOMIAL REGRESSION


import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

path = r"C:\1Aaaaaa5thsem\Hackoweek_2\eda_data.csv"

df = pd.read_csv(path)


features = ["Rating", "age"]
target = "avg_salary"


for column in features:
    df[column] = pd.to_numeric(df[column], errors="coerce")

df[target] = pd.to_numeric(df[target], errors="coerce")


df = df.dropna(subset=features + [target])


X = df[features]
y = df[target]


X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)


poly = PolynomialFeatures(
    degree=2,
    include_bias=False
)


X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)



model = LinearRegression()

model.fit(X_train_poly, y_train)

y_pred = model.predict(X_test_poly)



mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print("========== POLYNOMIAL REGRESSION ==========")

print("\nPolynomial Degree:", 2)
print("Number of training samples:", len(X_train))
print("Number of testing samples :", len(X_test))

print("\nMean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R2 Score:", r2)



print("\nPolynomial Features:")
print(poly.get_feature_names_out(features))



new_data = pd.DataFrame({
    "Rating": [4.0],
    "age": [10]
})


new_data_poly = poly.transform(new_data)

new_prediction = model.predict(new_data_poly)


print("\n========== NEW PREDICTION ==========")
print("Predicted Average Salary:", new_prediction[0])
# Out:
# ========== POLYNOMIAL REGRESSION ==========
#
# Polynomial Degree: 2
# Number of training samples: 593
# Number of testing samples : 149
#
# Mean Squared Error (MSE): 1565.2645579652853
# Mean Absolute Error (MAE): 30.52363665732026
# R2 Score: 0.04236534782553958
#
# Polynomial Features:
# ['Rating' 'age' 'Rating^2' 'Rating age' 'age^2']
#
# ========== NEW PREDICTION ==========
# Predicted Average Salary: 103.42408666458994

# %%
# EXPERIMENT 3: RIDGE REGRESSION

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


path = r"C:\1Aaaaaa5thsem\Hackoweek_2\eda_data.csv"

df = pd.read_csv(path)

features = ["Rating", "age", "desc_len", "num_comp"]
target = "avg_salary"


for column in features:
    df[column] = pd.to_numeric(df[column], errors="coerce")

df[target] = pd.to_numeric(df[target], errors="coerce")


df = df.dropna(subset=features + [target])

X = df[features]
y = df[target]


X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = Ridge(alpha=1.0)

model.fit(X_train_scaled, y_train)


y_pred = model.predict(X_test_scaled)


mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print("========== RIDGE REGRESSION ==========")

print("\nRegularization parameter (Alpha):", 1.0)
print("Number of training samples:", len(X_train))
print("Number of testing samples :", len(X_test))

print("\nMean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R2 Score:", r2)

print("\nModel Coefficients:")

for feature, coefficient in zip(features, model.coef_):
    print(feature, ":", coefficient)


new_data = pd.DataFrame({
    "Rating": [4.0],
    "age": [10],
    "desc_len": [3000],
    "num_comp": [2]
})


new_data_scaled = scaler.transform(new_data)

new_prediction = model.predict(new_data_scaled)

print("\n========== NEW PREDICTION ==========")
print("Predicted Average Salary:", new_prediction[0])
# Out:
# ========== RIDGE REGRESSION ==========
#
# Regularization parameter (Alpha): 1.0
# Number of training samples: 593
# Number of testing samples : 149
#
# Mean Squared Error (MSE): 1642.1801965215354
# Mean Absolute Error (MAE): 31.78456206051538
# R2 Score: -0.004691924634100841
#
# Model Coefficients:
# Rating : 1.4555544335472954
# age : 0.6544638838482157
# desc_len : 2.820721197050587
# num_comp : 3.061135199467678
#
# ========== NEW PREDICTION ==========
# Predicted Average Salary: 100.64244423560739

# %%
# EXPERIMENT 4: LASSO REGRESSION


import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


path = r"C:\1Aaaaaa5thsem\Hackoweek_2\eda_data.csv"

df = pd.read_csv(path)



features = ["Rating", "age", "desc_len", "num_comp"]
target = "avg_salary"


for column in features:
    df[column] = pd.to_numeric(df[column], errors="coerce")

df[target] = pd.to_numeric(df[target], errors="coerce")



df = df.dropna(subset=features + [target])



X = df[features]
y = df[target]



X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)



scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


model = Lasso(alpha=0.1)



model.fit(X_train_scaled, y_train)


y_pred = model.predict(X_test_scaled)



mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("========== LASSO REGRESSION ==========")

print("\nRegularization parameter (Alpha):", 0.1)
print("Number of training samples:", len(X_train))
print("Number of testing samples :", len(X_test))

print("\nMean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R2 Score:", r2)

print("\nModel Coefficients:")

for feature, coefficient in zip(features, model.coef_):
    print(feature, ":", coefficient)


print("\nFeatures with non-zero coefficients:")

for feature, coefficient in zip(features, model.coef_):
    if coefficient != 0:
        print(feature, ":", coefficient)


new_data = pd.DataFrame({
    "Rating": [4.0],
    "age": [10],
    "desc_len": [3000],
    "num_comp": [2]
})


new_data_scaled = scaler.transform(new_data)

new_prediction = model.predict(new_data_scaled)



print("\n========== NEW PREDICTION ==========")
print("Predicted Average Salary:", new_prediction[0])
# Out:
# ========== LASSO REGRESSION ==========
#
# Regularization parameter (Alpha): 0.1
# Number of training samples: 593
# Number of testing samples : 149
#
# Mean Squared Error (MSE): 1640.4566272259042
# Mean Absolute Error (MAE): 31.76762019998035
# R2 Score: -0.0036374385572768286
#
# Model Coefficients:
# Rating : 1.3545771161859823
# age : 0.5774383329801304
# desc_len : 2.7407388788175133
# num_comp : 2.984288484720654
#
# Features with non-zero coefficients:
# Rating : 1.3545771161859823
# age : 0.5774383329801304
# desc_len : 2.7407388788175133
# num_comp : 2.984288484720654
#
# ========== NEW PREDICTION ==========
# Predicted Average Salary: 100.6391452656891

# %%
# LOGISTIC REGRESSION


import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)



path = r"C:\1Aaaaaa5thsem\Hackoweek_2\eda_data.csv"

df = pd.read_csv(path)

features = ["Rating", "age", "desc_len", "num_comp"]
target = "python_yn"


for column in features:
    df[column] = pd.to_numeric(df[column], errors="coerce")

df[target] = pd.to_numeric(df[target], errors="coerce")


df = df.dropna(subset=features + [target])


X = df[features]
y = df[target].astype(int)



print("========== DATASET INFORMATION ==========")

print("\nClass Distribution:")
print(y.value_counts())



X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)



scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)



model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

model.fit(X_train_scaled, y_train)



y_pred = model.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)



print("\n========== LOGISTIC REGRESSION ==========")

print("\nNumber of training samples:", len(X_train))
print("Number of testing samples :", len(X_test))

print("\nAccuracy:", accuracy)



print("\nConfusion Matrix:")

cm = confusion_matrix(y_test, y_pred)

print(cm)


print("\nClassification Report:")

print(classification_report(y_test, y_pred))

print("Model Coefficients:")

for feature, coefficient in zip(features, model.coef_[0]):
    print(feature, ":", coefficient)

new_data = pd.DataFrame({
    "Rating": [4.0],
    "age": [10],
    "desc_len": [3000],
    "num_comp": [2]
})



new_data_scaled = scaler.transform(new_data)



prediction = model.predict(new_data_scaled)

probability = model.predict_proba(new_data_scaled)



print("\n========== NEW PREDICTION ==========")

if prediction[0] == 1:
    print("Prediction: Python Required")
else:
    print("Prediction: Python Not Required")

print("\nProbability of Python Not Required:", probability[0][0])
print("Probability of Python Required    :", probability[0][1])
# Out:
# ========== DATASET INFORMATION ==========
#
# Class Distribution:
# python_yn
# 1    392
# 0    350
# Name: count, dtype: int64
#
# ========== LOGISTIC REGRESSION ==========
#
# Number of training samples: 593
# Number of testing samples : 149
#
# Accuracy: 0.6711409395973155
#
# Confusion Matrix:
# [[35 35]
#  [14 65]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.50      0.59        70
#            1       0.65      0.82      0.73        79
#
#     accuracy                           0.67       149
#    macro avg       0.68      0.66      0.66       149
# weighted avg       0.68      0.67      0.66       149
#
# Model Coefficients:
# Rating : 0.35035132869353114
# age : -0.2204939021279044
# desc_len : 0.09329873690789851
# num_comp : 0.13828497101632387
#
# ========== NEW PREDICTION ==========
# Prediction: Python Required
#
# Probability of Python Not Required: 0.38351202961240494
# ...

# %%
#K-NEAREST NEIGHBORS (KNN)


import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)


# ------------------------------------------------------------
# 1. Load dataset
# ------------------------------------------------------------

path = r"C:\1Aaaaaa5thsem\Hackoweek_2\eda_data.csv"

df = pd.read_csv(path)


# ------------------------------------------------------------
# 2. Select features and target
# ------------------------------------------------------------

features = ["Rating", "age", "desc_len", "num_comp"]
target = "python_yn"


# ------------------------------------------------------------
# 3. Convert columns to numeric
# ------------------------------------------------------------

for column in features:
    df[column] = pd.to_numeric(df[column], errors="coerce")

df[target] = pd.to_numeric(df[target], errors="coerce")


# ------------------------------------------------------------
# 4. Remove missing values
# ------------------------------------------------------------

df = df.dropna(subset=features + [target])


# ------------------------------------------------------------
# 5. Create X and y
# ------------------------------------------------------------

X = df[features]
y = df[target].astype(int)


# ------------------------------------------------------------
# 6. Display class distribution
# ------------------------------------------------------------

print("========== DATASET INFORMATION ==========")

print("\nClass Distribution:")
print(y.value_counts())


# ------------------------------------------------------------
# 7. Split dataset
# ------------------------------------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)


# ------------------------------------------------------------
# 8. Standardize features
# ------------------------------------------------------------

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# ------------------------------------------------------------
# 9. Create KNN model
# ------------------------------------------------------------

k = 5

model = KNeighborsClassifier(
    n_neighbors=k
)


# ------------------------------------------------------------
# 10. Train the model
# ------------------------------------------------------------

model.fit(X_train_scaled, y_train)


# ------------------------------------------------------------
# 11. Make predictions
# ------------------------------------------------------------

y_pred = model.predict(X_test_scaled)


# ------------------------------------------------------------
# 12. Calculate accuracy
# ------------------------------------------------------------

accuracy = accuracy_score(y_test, y_pred)


# ------------------------------------------------------------
# 13. Display results
# ------------------------------------------------------------

print("\n========== K-NEAREST NEIGHBORS ==========")

print("\nNumber of Neighbors (K):", k)
print("Number of training samples:", len(X_train))
print("Number of testing samples :", len(X_test))

print("\nAccuracy:", accuracy)


# ------------------------------------------------------------
# 14. Display confusion matrix
# ------------------------------------------------------------

print("\nConfusion Matrix:")

cm = confusion_matrix(y_test, y_pred)

print(cm)


# ------------------------------------------------------------
# 15. Display classification report
# ------------------------------------------------------------

print("\nClassification Report:")

print(classification_report(y_test, y_pred))


# ------------------------------------------------------------
# 16. Predict a new data point
# ------------------------------------------------------------

new_data = pd.DataFrame({
    "Rating": [4.0],
    "age": [10],
    "desc_len": [3000],
    "num_comp": [2]
})


# Scale new data
new_data_scaled = scaler.transform(new_data)


# Make prediction
prediction = model.predict(new_data_scaled)

probability = model.predict_proba(new_data_scaled)


# ------------------------------------------------------------
# 17. Display new prediction
# ------------------------------------------------------------

print("\n========== NEW PREDICTION ==========")

if prediction[0] == 1:
    print("Prediction: Python Required")
else:
    print("Prediction: Python Not Required")

print("\nProbability of Python Not Required:", probability[0][0])
print("Probability of Python Required    :", probability[0][1])
# Out:
# ========== DATASET INFORMATION ==========
#
# Class Distribution:
# python_yn
# 1    392
# 0    350
# Name: count, dtype: int64
#
# ========== K-NEAREST NEIGHBORS ==========
#
# Number of Neighbors (K): 5
# Number of training samples: 593
# Number of testing samples : 149
#
# Accuracy: 0.6577181208053692
#
# Confusion Matrix:
# [[43 27]
#  [24 55]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.61      0.63        70
#            1       0.67      0.70      0.68        79
#
#     accuracy                           0.66       149
#    macro avg       0.66      0.66      0.66       149
# weighted avg       0.66      0.66      0.66       149
#
#
# ========== NEW PREDICTION ==========
# Prediction: Python Required
#
# Probability of Python Not Required: 0.4
# Probability of Python Required    : 0.6
